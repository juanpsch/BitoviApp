# %%
from config import llm
from langchain_core.messages import SystemMessage, HumanMessage
from agent.graph import app
app

# %%
from langgraph.graph import StateGraph, START, END
from agent.state import AgentState
from langgraph.prebuilt import ToolNode, tools_condition
from agent.nodes import intent_analyzer_node, analysis_node, retrieval_node, generator_node, expansion_node, grade_retrieval
from scripts.my_tools import retrieve_docs

# %%
workflow = StateGraph(AgentState)

# Nodos
workflow.add_node("intent_analyzer", intent_analyzer_node)
workflow.add_node("analizar", analysis_node)

workflow.set_entry_point("intent_analyzer")
workflow.add_edge("intent_analyzer", "analizar")

workflow.add_edge("analizar", END)

apptest = workflow.compile()
apptest

# %%
q = "Whats the last article about?"
q = "List me the last post related to Inteligencia Artificial"
# q="List me all post related to RAG"
# q="list articles or testing of 2024"
# # q = "what is amazon's revenue in 2024?"
q = "whats a vector store?"
# q = "Whats is the last article about?"
# q = "Last article about?"
# q = "Whats Retreival Augmnted Generation?"
# q = "whats the last article about?"
q = "Whats a Rag?"


q = "What is Bitovi's latest blog post about?"
q = "Can you show me all Bitovi articles about DevOps?"
# q = "How many articles does Bitovi have about AI?"
# q = "What kind of tools does Bitovi recommend for E2E testing?"



result = app.invoke({'messages': [HumanMessage(q)]})

result['messages'][-1].pretty_print()
# Out:
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.LISTING | Reason: The user wants to see a list of available resources or documents, blogs, articles, or posts. The goal is to retrieve the document containers.
# --- [ANALYSIS] Analizando query: Can you show me all Bitovi articles about DevOps? ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': None, 'top_k': 50}
#
# [NODE] Query: Can you show me all Bitovi articles about DevOps?
# [NODE] Strategic Route: RetrievalRoute.CONVENCIONAL
# [NODE] Params from Analyzer: {'sort_by': None, 'top_k': 50}
#
# [TOOL] retrieve_docs called for query: Bitovi articles about DevOps
# --- [TOOL] Ejecutando búsqueda para ruta: RetrievalRoute.CONVENCIONAL ---
# [TOOL] Usando parámetros del Analyzer -> Route: RetrievalRoute.CONVENCIONAL, Sort: None, TopK: 50
# [TOOL] Filters: {'category': 'DevOps'}
# [MODE] Convencional - Ranking Keywords: []
# [MODE] Skipping Re-rank: No keywords found
# [TOOL] Aplicando post-proceso: Sort by None, Limit 50
#
# --- [NODE] Generando respuesta final ---
# ================================== Ai Message ==================================
#
# Based on the provided documents, I will identify some common themes and patterns.
#
# **Common Themes:**
#
# 1. **Temporal**: Many articles discuss Temporal, a workflow orchestration tool, including its benefits, use cases, and comparisons with other tools like Apache Airflow.
# 2. **DevOps**: Several articles focus on DevOps practices, such as Continuous Integration (CI), Continuous Deployment (CD), and Infrastructure as Code (IaC).
# 3. **Security**: Some articles discuss security-related topics, like implementing role-based authentication for self-hosted Temporal deployments.
# 4. **Cloud Computing**: Articles mention cloud platforms like AWS EC2, Google Cloud Platform, and Azure.
#
# **Patterns:**
#
# 1. **Technical tutorials**: Many articles provide step-by-step guides on how to use specific tools or technologies, such as setting up a Temporal workflow or deploying an application to AWS EC2.
# 2. **Comparisons and migrations**: Articles often compare different tools or technologies, highlighting their strengths and weaknesses, and providing guidance on migrating from one tool to another (e.g., Apache Airflow to Temporal).
# 3. **Best practices**: Some articles focus on DevOps best practices, such as managing repository configuration, implementing CI/CD pipelines, and ensuring security in self-hosted environments.
# 4. **Case studies and examples**: Articles may include real-world examples or case studies to illustrate the application of specific technologies or techniques.
#
# **Tools and Technologies:**
#
# 1. **Temporal**: A workflow orchestration tool for building scalable and fault-tolerant workflows.
# 2. **Apache Airflow**: A platform for programmatically defining, scheduling, and monitoring workflows.
# 3. **AWS EC2**: A cloud computing service that provides virtual servers in the cloud.
# 4. **Node.js**: A JavaScript runtime environment for building server-side applications.
#
# **Target Audience:**
#
# 1. **Developers**: Articles are written primarily for developers who want to learn about specific technologies or tools, such as Temporal or AWS EC2.
# 2. **DevOps professionals**: Some articles cater to DevOps professionals interested in best practices, security, and infrastructure management.
# 3. **System administrators**: Articles may also be relevant to system administrators responsible for managing cloud environments and ensuring security.
#
# Overall, the documents cover a range of topics related to software development, DevOps, and cloud computing, with a focus on practical tutorials, comparisons, and best practices.

# %%
# q = "Whats a RAG?"
q = "whats the last article about?"

result = apptest.invoke({'messages': [HumanMessage(q)]})
# Out:
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the topic of the last article, which is a content-based question.
# --- [ANALYSIS] Analizando query: whats the last article about? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': 'date_ts', 'top_k': 1}

# %%
qs= [
    "Whats the last article about?",
    "List me the last post related to Inteligencia Artificial",
    "List me all post related to RAG",
    "list articles or testing of 2024",
    "what is amazon's revenue in 2024?",
    "whats a vector store?",
    "Whats is the last article about?",
    "Last article about?",
    "Whats Retreival Augmnted Generation?",
    "whats the last article about?",
    "Whats a Rag?"
    ]

# %%
for q in qs:
    apptest.invoke({'messages': [HumanMessage(q)]})
# Out:
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the topic of the last article, which is a content-based question.
# --- [ANALYSIS] Analizando query: Whats the last article about? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': 'date_ts', 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.LISTING | Reason: The user wants to see a list of available resources or documents, blogs, articles or posts. The keyword 'last' indicates they want the most recent one.
# --- [ANALYSIS] Analizando query: List me the last post related to Inteligencia Artificial ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': 'date_ts', 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.LISTING | Reason: The user wants a list of posts related to RAG, which is a specific topic. The goal is to retrieve the container (post) rather than understanding its content.
# --- [ANALYSIS] Analizando query: List me all post related to RAG ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': None, 'top_k': 10}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.LISTING | Reason: The user wants to see a list of available resources or documents, blogs, articles, or posts related to 'articles' or 'testing' for the year '2024'. The keywords 'list', 'show me', and 'which posts' are indicative of this intent.
# --- [ANALYSIS] Analizando query: list articles or testing of 2024 ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': None, 'top_k': 10}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to know Amazon's revenue for a specific year, which falls under the category of SINTESIS. The goal is to extract and provide a definition or explanation of Amazon's revenue for 2024.
# --- [ANALYSIS] Analizando query: what is amazon's revenue in 2024? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': None, 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand what a vector store is, which is a conceptual definition.
# --- [ANALYSIS] Analizando query: whats a vector store? ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': None, 'top_k': 10}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the topic of the last article, which falls under the category of SINTESIS. The goal is to extract knowledge from the content of the document.
# --- [ANALYSIS] Analizando query: Whats is the last article about? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': 'date_ts', 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the topic of the last article, which is a definition/explanation of content.
# --- [ANALYSIS] Analizando query: Last article about? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': None, 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user is asking for a definition of a technical term, which falls under the SINTESIS category. The goal is to understand what Retrieval-Augmented Generation (RAG) means.
# --- [ANALYSIS] Analizando query: Whats Retreival Augmnted Generation? ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': None, 'top_k': 10}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the topic of the last article, which is a content-based question.
# --- [ANALYSIS] Analizando query: whats the last article about? ---
# [ANALYSIS] Route: RetrievalRoute.FAST | Params: {'sort_by': 'date_ts', 'top_k': 1}
#
# --- [NODE] Clasificando Intención del Usuario ---
# [INTENT] Type: TaskType.SINTESIS | Reason: The user wants to understand the definition of 'Rag', which is a technical term. The goal is to extract knowledge from it, not just find the file.
# --- [ANALYSIS] Analizando query: Whats a Rag? ---
# [ANALYSIS] Route: RetrievalRoute.CONVENCIONAL | Params: {'sort_by': None, 'top_k': 10}
